# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from train import run

# %%
def test_loss_for_H(_,__):
    return torch.abs(modelH()-torch.ones_like(modelH())).sum()

# %%
opts = ['GENERAL.device', 'cuda:1']
config_file= 'configs/test.yaml'

# %%
run(config_file=config_file, opts= opts)
# Out:
# load config file : configs/test.yaml
# Overide opts :  ['GENERAL.device', 'cuda:1']
# DATASET:
#   batch_size: 32
#   delta: 1e-06
#   img_channels: 1
#   img_size: 32
# GENERAL:
#   device: cuda:1
#   save_dir: figs/test
#   torch_seed: 10
# MODEL:
#   MODEL_A:
#     exPSF: torch.tensor(get_gaussian(side_len=5, s=1)).float().to(device)
#     noise: True
#     rotation_lambda: 1000
#     sPSF: torch.tensor(get_gaussian(side_len=5, s=1)).float().to(device)
#     scale_factor: 1
#     shift_lambda_real: 0
#   MODEL_DECODER:
#     channel_list: [12, 10, 4, 3, 2]
#     last_activation: None
#     lr_decoder: 0.001
#   MODEL_H:
#     H_activation: sigmoid_custom
#     H_complex_init: False
#     H_init: fft
#     H_weight_preprocess: ifft_2d_with_fftshift_real
#     T: 16
#     enable_train: True
#     initialization_bias: 0
#     lr_H: 100
# NAME: Experiment
# TRAIN:
#   classifier: None
#   criterion: nn.L1Loss().to(device)
#   epochs: 10
#   m_inc_proc: inc_1_after_60_interval_10
# ...
