# %%
# %load_ext autoreload
# %autoreload 2

from main_reconstruction_swinIR_wforward import safe_do_exps

# %%
name= 'bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalHtDefaultUpsample'

exp_dir= f'../figs/{name}' #'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs'
save_dir_special_root = f'../figs/{name}' #f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/{name}'

# !rm -rf $exp_dir
# !mkdir $exp_dir

# !rm -rf $save_dir_special_root
# !mkdir $save_dir_special_root

# %%
count_only = False

device = 'cuda:0'

exps = {
        'DATASET.name': ['bbbcHumanMCF7cellsW4'],
    
        'MODEL.MODEL_A.rotation_lambda': ['10000.0'],
        'MODEL.MODEL_A.lambda_scale_factor': ['3'],
        'MODEL.MODEL_H.T': ['1'], 
        'MODEL.MODEL_H.lr_H': ['1.0'],
    
        'DATASET.img_size':  ['64'], #256
        'DATASET.num_samples_train': ['3000'], #'10000-> 1400 sec/ epoch' , 3000-> 440 sec/ epoch (18.3hrs/ exp)  
        'DATASET.num_samples_valtest': ['25'],
        'DATASET.batch_size_train': ['8'], #32
}

general_opts= ['TRAIN.show_results_epoch', '1', #5
                'TRAIN.epochs', '3']  #150


safe_do_exps(exps, general_opts, device, exp_dir = exp_dir, save_special= True, count_only= count_only, save_dir_special_root= save_dir_special_root)
# Out:
# number of total experiments : 1
# running  -> ../figs/bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalHtDefaultUpsample/name(bbbcHumanMCF7cellsW4)@rotation_lambda(10000.0)@lambda_scale_factor(3)@T(1)@img_size(64)@num_samples_train(3000)@num_samples_valtest(25)@batch_size_train(8)
# Overide opts :  ['NAME', 'exp_idx(1)', 'GENERAL.device', 'cuda:0', 'GENERAL.save_dir', '../figs/bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalHtDefaultUpsample/name(bbbcHumanMCF7cellsW4)@rotation_lambda(10000.0)@lambda_scale_factor(3)@T(1)@img_size(64)@num_samples_train(3000)@num_samples_valtest(25)@batch_size_train(8)', 'TRAIN.show_results_epoch', '1', 'TRAIN.epochs', '3', 'DATASET.name', 'bbbcHumanMCF7cellsW4', 'MODEL.MODEL_A.rotation_lambda', '10000.0', 'MODEL.MODEL_A.lambda_scale_factor', '3', 'MODEL.MODEL_H.T', '1', 'DATASET.img_size', '64', 'DATASET.num_samples_train', '3000', 'DATASET.num_samples_valtest', '25', 'DATASET.batch_size_train', '8']
# DATASET:
#   batch_size_train: 8
#   delta: 1e-06
#   img_channels: 1
#   img_size: 64
#   name: bbbcHumanMCF7cellsW4
#   num_samples_train: 3000
#   num_samples_valtest: 25
# GENERAL:
#   device: cuda:0
#   other_opt_dir: None
#   save_dir: ../figs/bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalHtDefaultUpsample/name(bbbcHumanMCF7cellsW4)@rotation_lambda(10000.0)@lambda_scale_factor(3)@T(1)@img_size(64)@num_samples_train(3000)@num_samples_valtest(25)@batch_size_train(8)
#   torch_seed: 10
# MODEL:
#   MODEL_A:
#     exPSF: impulse(side_len=5)
#     lambda_scale_factor: 3
#     noise: True
#     readnoise_std: 0.0
#     rotation_lambda: 10000.0
#     sPSF: impulse(side_len=5)
#     shift_lambda_real: 10.0
#   MODEL_DECODER:
#     channel_list: [24, 12, 8, 4, 2]
#     connect_forward_inverse: no_skips
#     custom_upsampling_bias: True
#     last_activation: sigmoid
#     lr_decoder: 0.001
#     name: genv1
#     upsample_net: custom_v2
#     upsample_net_init_method: xavier_normal
#   MODEL_H:
#     H_activation: sigmoid_custom
#     H_init: randn_FourierBased
#     H_weight_preprocess: ifft_2d_with_fftshift_real
#     T: 1
#     initialization_bias: 0
#     lr_H: 0.0
# NAME: exp_idx(1)
# TRAIN:
#   classifier: None
#   criterion: nn.L1Loss().to(device)
#   epochs: 3
#   m_inc_proc: inc_m_class(epoch_threshold= 80, epoch_steps= 10)
#   rescale_for_classifier: None
#   show_results_epoch: 1
#   train_H_iter: 1
#   train_model_iter: 1
# skip connection between FORWARD and INVERSE models :: no_skips
# MODEL_H : enable_train ::: False (derived from lr_H)
# len(results_saving_folder) : 160 (<= 255)
# total images found in: /home/udith/udith_works/datasets/bbbcHumanMCF7cells/preprocessed/w4/train -> 206976
# total images found in: /home/udith/udith_works/datasets/bbbcHumanMCF7cells/preprocessed/w4/val -> 2112
# total images found in: /home/udith/udith_works/datasets/bbbcHumanMCF7cells/preprocessed/w4/test -> 2112
# dataset lenths : 3000 | 25 | 25
# dataset value range :  0.007844130508601665 0.7137258648872375
# ** default other opt dir is used : None
# ../adversarial_learning/swinIRwforward_support_files/models_define.py:123: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   opt = yaml.load(file)
# /home/udith/miniconda3/envs/deepTFM/lib/python3.6/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1640811805959/work/aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Pass this initialization! Initialization was done during network defination!
# Initialization method [orthogonal + uniform], gain is [0.20]
# Pass this initialization! Initialization was done during network defination!
# Sequential(
#   (child0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (child1): Sequential(
#     (0): ReLU(inplace=True)
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (child2): Sequential(
#     (0): ReLU(inplace=True)
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(inplace=True)
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (child3): Sequential(
#     (0): ReLU(inplace=True)
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(inplace=True)
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (child4): Sequential(
#     (0): ReLU(inplace=True)
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU(inplace=True)
#     (6): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )
# feature_layer: [2, 7, 16, 25, 34]  with weights: [0.1, 0.1, 1.0, 1.0, 1.0]
# Params [modelH.weights] will not optimize.
# device : cuda:0
# m : 1
# /home/udith/miniconda3/envs/deepTFM/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /home/udith/miniconda3/envs/deepTFM/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:154: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# after 1 epochs... yt_down range (train): [0.04631771519780159 2.1212637424468994]
# after 1 epochs... yt_down range (test): [0.043156981468200684 3.8602612018585205]
# training loop time (for epoch: 1): 75.96024656295776 sec
# validation loop time (for epoch: 1): 0.10518264770507812 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 1
# after 2 epochs... yt_down range (train): [0.04495110362768173 3.1950302124023438]
# after 2 epochs... yt_down range (test): [0.04602554067969322 3.8496615886688232]
# training loop time (for epoch: 2): 78.06363558769226 sec
# validation loop time (for epoch: 2): 0.08972740173339844 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 1
# after 3 epochs... yt_down range (train): [0.045922137796878815 3.2828714847564697]
# after 3 epochs... yt_down range (test): [0.03954729437828064 3.8850035667419434]
# training loop time (for epoch: 3): 77.70717334747314 sec
# validation loop time (for epoch: 3): 0.09042882919311523 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# COUNT ONLY (no exps running/ deleting) : False
# count_already_trained (tot_epochs completed):  0
# count_train_from_begining :  1
# count_train_from_begining (after deleting existing exp) :  0

# %%
# %%writefile evalHt2.py
from main_reconstruction_swinIRwCustomUp_wforward import safe_do_exps

name= 'bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalHtDefaultUpsample'

exp_dir= f'../figs/{name}' #'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs'
save_dir_special_root = f'../figs/{name}' #f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/{name}'

import shutil, os

shutil.rmtree(exp_dir)
os.mkdir(exp_dir)
shutil.rmtree(save_dir_special_root)
os.mkdir(save_dir_special_root)

count_only = False

device = 'cuda:0'

exps = {
        'DATASET.name': ['bbbcHumanMCF7cellsW4'],
    
        'MODEL.MODEL_A.rotation_lambda': ['10000.0'],
        'MODEL.MODEL_A.lambda_scale_factor': ['3'],
        'MODEL.MODEL_H.T': ['1'], 
        #'MODEL.MODEL_H.lr_H': ['0.0'],
    
        'DATASET.img_size':  ['64'], #256
        'DATASET.num_samples_train': ['3000'], #'10000-> 1400 sec/ epoch' , 3000-> 440 sec/ epoch (18.3hrs/ exp)  
        'DATASET.num_samples_valtest': ['25'],
        'DATASET.batch_size_train': ['8'], #32
}

general_opts= ['TRAIN.show_results_epoch', '1', #5
                'TRAIN.epochs', '3']  #150


safe_do_exps(exps, general_opts, device, exp_dir = exp_dir, save_special= True, count_only= count_only, save_dir_special_root= save_dir_special_root)
# Out:
# Writing evalHt2.py
