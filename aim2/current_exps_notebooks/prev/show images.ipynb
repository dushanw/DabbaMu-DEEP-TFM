# %%
import shutil, glob, os
import matplotlib.pyplot as plt
import torch
import numpy as np
import torchvision
import cv2

# %%
dir1 = f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/bbbcHumanMCF7cellsW4v3'
dir2 = f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/bbbcHumanMCF7cellsW4v1'

H_init= ['randn_FourierBased', 'uniformones_FourierBased'][1]
x_val_dir = glob.glob(f'{dir1}/*H_init({H_init})*/save_special/150_X_val.npy')[0]
x_hat_val_dir = glob.glob(f'{dir1}/*H_init({H_init})*/save_special/150_X_hat_val.npy')[0]

#x_val_dir = glob.glob(f'{dir2}/*lambda_scale_factor(5)*lr_H(1.0)*/save_special/150_X_val.npy')[0]
#x_hat_val_dir = glob.glob(f'{dir2}/*lambda_scale_factor(5)*lr_H(1.0)*/save_special/150_X_hat_val.npy')[0]


plt.figure(figsize= (30, 15))
plt.subplot(1,2,1)
x_val= torch.from_numpy(np.load(x_val_dir))
grid_img = torchvision.utils.make_grid(x_val, nrow=5)
img= cv2.cvtColor(grid_img.permute(1,2,0).numpy(), cv2.COLOR_RGB2GRAY)
plt.imshow(img)
vmin, vmax= img.min(), img.max()
plt.title('real')

plt.subplot(1,2,2)
x_hat_val= torch.from_numpy(np.load(x_hat_val_dir))
grid_img = torchvision.utils.make_grid(x_hat_val, nrow=5)
plt.imshow(cv2.cvtColor(grid_img.permute(1,2,0).numpy(), cv2.COLOR_RGB2GRAY), vmin= vmin, vmax= vmax)
plt.title('pred')
plt.show()

# %%
import numpy as np

# %%
import torch, torchvision
import matplotlib.pyplot as plt
import cv2

# %%
# !mkdir ./results/

# %%
for weight in ['0', '10', '100', '1000']:
    if weight=='0':
        dir = f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/bbbcHumanMCF7cellsW4v1'
        x_val_dir = glob.glob(f'{dir}/*lambda_scale_factor(5)*lr_H(1.0)*/save_special/150_X_val.npy')[0]
        x_hat_val_dir = glob.glob(f'{dir}/*lambda_scale_factor(5)*lr_H(1.0)*/save_special/150_X_hat_val.npy')[0]

    else:
        dir_ = f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/bbbcHumanMCF7cellsW4v2'
        x_val_dir = glob.glob(f'{dir_}/*HighFreqWeightedL1({weight})*lr_H(1.0)*/save_special/150_X_val.npy')[0]
        x_hat_val_dir = glob.glob(f'{dir_}/*HighFreqWeightedL1({weight})*lr_H(1.0)*/save_special/150_X_hat_val.npy')[0]

    plt.figure(figsize= (30, 15))
    plt.subplot(1,2,1)
    x_val= torch.from_numpy(np.load(x_val_dir))
    grid_img = torchvision.utils.make_grid(x_val, nrow=5)
    img= cv2.cvtColor(grid_img.permute(1,2,0).numpy(), cv2.COLOR_RGB2GRAY)
    plt.imshow(img)
    vmin, vmax= img.min(), img.max()
    plt.title('real')

    plt.subplot(1,2,2)
    x_hat_val= torch.from_numpy(np.load(x_hat_val_dir))
    grid_img = torchvision.utils.make_grid(x_hat_val, nrow=5)
    plt.imshow(cv2.cvtColor(grid_img.permute(1,2,0).numpy(), cv2.COLOR_RGB2GRAY), vmin= vmin, vmax= vmax)
    plt.title('pred')
    plt.suptitle(f'weight : {weight}')
    
    plt.savefig(f'./results/weight({weight}).png')
    plt.show()

# %%
for weight in ['0', '10', '100', '1000']:
    if weight=='0':
        dir = f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/bbbcHumanMCF7cellsW4v1'
        x_val_dir = glob.glob(f'{dir}/*lambda_scale_factor(5)*lr_H(1.0)*/save_special/150_X_val.npy')[0]
        x_hat_val_dir = glob.glob(f'{dir}/*lambda_scale_factor(5)*lr_H(1.0)*/save_special/150_X_hat_val.npy')[0]

    else:
        dir_ = f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/bbbcHumanMCF7cellsW4v2'
        x_val_dir = glob.glob(f'{dir_}/*HighFreqWeightedL1({weight})*lr_H(1.0)*/save_special/150_X_val.npy')[0]
        x_hat_val_dir = glob.glob(f'{dir_}/*HighFreqWeightedL1({weight})*lr_H(1.0)*/save_special/150_X_hat_val.npy')[0]

    plt.figure(figsize= (30, 15))
    plt.subplot(1,2,1)
    x_val= torch.from_numpy(np.load(x_val_dir))
    grid_img = torchvision.utils.make_grid(x_val[[0, 12, 15, 18]], nrow=2)
    img= cv2.cvtColor(grid_img.permute(1,2,0).numpy(), cv2.COLOR_RGB2GRAY)
    plt.imshow(img)
    vmin, vmax= img.min(), img.max()
    plt.title('real')

    plt.subplot(1,2,2)
    x_hat_val= torch.from_numpy(np.load(x_hat_val_dir))
    grid_img = torchvision.utils.make_grid(x_hat_val[[0, 12, 15, 18]], nrow=2)
    plt.imshow(cv2.cvtColor(grid_img.permute(1,2,0).numpy(), cv2.COLOR_RGB2GRAY), vmin= vmin, vmax= vmax)
    plt.title('pred')
    plt.suptitle(f'weight : {weight}')
    
    plt.savefig(f'./results/weight({weight}).png')
    plt.show()

# %%
idx=0

weight='0'
dir = f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/bbbcHumanMCF7cellsW4v1'
x_val_dir = glob.glob(f'{dir}/*lambda_scale_factor(5)*lr_H(1.0)*/save_special/150_X_val.npy')[0]
x_hat_val_dir = glob.glob(f'{dir}/*lambda_scale_factor(5)*lr_H(1.0)*/save_special/150_X_hat_val.npy')[0]

plt.figure(figsize= (10, 10))
x_val= torch.from_numpy(np.load(x_val_dir))
vmin, vmax= x_val[idx,0].min(), x_val[idx,0].max()
plt.imshow(x_val[idx,0], vmin=vmin, vmax=vmax)
plt.axis('off')
plt.savefig(f'./results/idx({idx})_final_gt.png', dpi= 500)
plt.show()

plt.figure(figsize= (10, 10))
x_hat_val= torch.from_numpy(np.load(x_hat_val_dir))
plt.imshow(x_hat_val[idx,0], vmin=vmin, vmax=vmax)
plt.axis('off')
plt.savefig(f'./results/idx({idx})_final_pred_our.png', dpi= 500)
plt.show()

dir_ = f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/bbbcHumanMCF7cellsW4v1'
H_init= 'randn_FourierBased'
x_val_dir = glob.glob(f'{dir1}/*H_init({H_init})*/save_special/150_X_val.npy')[0]
x_hat_val_dir = glob.glob(f'{dir1}/*H_init({H_init})*/save_special/150_X_hat_val.npy')[0]

plt.figure(figsize= (10, 10))
x_hat_val= torch.from_numpy(np.load(x_hat_val_dir))
plt.imshow(x_hat_val[idx,0], vmin=vmin, vmax=vmax)
plt.axis('off')
plt.savefig(f'./results/idx({idx})_final_pred_prev.png', dpi= 500)
plt.show()
