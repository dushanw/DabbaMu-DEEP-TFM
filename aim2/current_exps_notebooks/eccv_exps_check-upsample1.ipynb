# %%
# %load_ext autoreload
# %autoreload 2

from main_reconstruction_swinIRwCustomUp import safe_do_exps
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !ls ../figs/
# Out:
# bbbcHumanMCF7cellsW4_swinIRwCustomV2_x16_comp

# %%
name= 'bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalUpsample_our'

exp_dir= f'../figs/{name}' #'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs'
save_dir_special_root = f'../figs/{name}' #f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/{name}'

# !rm -rf $exp_dir
# !mkdir $exp_dir

# !rm -rf $save_dir_special_root
# !mkdir $save_dir_special_root

# %%
count_only = False

device = 'cuda:0'

exps = {
        'DATASET.name': ['bbbcHumanMCF7cellsW4'],
    
        'MODEL.MODEL_A.rotation_lambda': ['10000.0'],
        'MODEL.MODEL_A.lambda_scale_factor': ['3'],
        'MODEL.MODEL_H.T': ['1'], 
        'MODEL.MODEL_H.lr_H': ['0.0'],
    
        'DATASET.img_size':  ['64'], #256
        'DATASET.num_samples_train': ['3000'], #'10000-> 1400 sec/ epoch' , 3000-> 440 sec/ epoch (18.3hrs/ exp)  
        'DATASET.num_samples_valtest': ['25'],
        'DATASET.batch_size_train': ['8'], #32
}

general_opts= ['TRAIN.show_results_epoch', '5', #5
                'TRAIN.epochs', '150']  #150


safe_do_exps(exps, general_opts, device, exp_dir = exp_dir, save_special= True, count_only= count_only, save_dir_special_root= save_dir_special_root)
# Out:
# after 4 epochs... yt_down range (train): [0.04798627644777298 1.3038427829742432]
# after 4 epochs... yt_down range (test): [0.04554205760359764 3.872255802154541]
# training loop time (for epoch: 4): 273.5095498561859 sec
# validation loop time (for epoch: 4): 0.7545015811920166 sec
#
#
# m : 1
# after 5 epochs... yt_down range (train): [0.044364385306835175 3.3144328594207764]
# after 5 epochs... yt_down range (test): [0.04571693018078804 3.831064462661743]
# training loop time (for epoch: 5): 273.9588532447815 sec
# validation loop time (for epoch: 5): 0.7524373531341553 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 1
# after 6 epochs... yt_down range (train): [0.06513482332229614 2.8837106227874756]
# after 6 epochs... yt_down range (test): [0.04322916641831398 3.8498470783233643]
# training loop time (for epoch: 6): 273.03898763656616 sec
# validation loop time (for epoch: 6): 0.7528073787689209 sec
#
#
# m : 1
# after 7 epochs... yt_down range (train): [0.049802400171756744 4.405065536499023]
# after 7 epochs... yt_down range (test): [0.04313484579324722 3.8548810482025146]
# training loop time (for epoch: 7): 272.92312574386597 sec
# validation loop time (for epoch: 7): 0.7529482841491699 sec
#
#
# m : 1
# after 8 epochs... yt_down range (train): [0.04530226066708565 1.949849009513855]
# after 8 epochs... yt_down range (test): [0.04291864484548569 3.865281581878662]
# training loop time (for epoch: 8): 273.2439453601837 sec
# validation loop time (for epoch: 8): 0.7536072731018066 sec
#
#
# m : 1
# after 9 epochs... yt_down range (train): [0.04659852758049965 2.432525157928467]
# after 9 epochs... yt_down range (test): [0.0437496155500412 3.8252925872802734]
# training loop time (for epoch: 9): 272.67181515693665 sec
# validation loop time (for epoch: 9): 0.7541389465332031 sec
#
#
# m : 1
# after 10 epochs... yt_down range (train): [0.04446755349636078 2.6790149211883545]
# after 10 epochs... yt_down range (test): [0.0411003939807415 3.842496395111084]
# training loop time (for epoch: 10): 272.28508043289185 sec
# validation loop time (for epoch: 10): 0.7526159286499023 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 1
# after 11 epochs... yt_down range (train): [0.06775245070457458 1.7919434309005737]
# after 11 epochs... yt_down range (test): [0.04398702457547188 3.8463294506073]
# training loop time (for epoch: 11): 272.63954734802246 sec
# validation loop time (for epoch: 11): 0.7525584697723389 sec
#
#
# m : 1
# after 12 epochs... yt_down range (train): [0.058381468057632446 2.301283836364746]
# after 12 epochs... yt_down range (test): [0.04403894767165184 3.85097074508667]
# training loop time (for epoch: 12): 273.0833215713501 sec
# validation loop time (for epoch: 12): 0.7527017593383789 sec
#
#
# m : 1
# after 13 epochs... yt_down range (train): [0.05958801507949829 2.080404043197632]
# after 13 epochs... yt_down range (test): [0.04400341212749481 3.8607356548309326]
# training loop time (for epoch: 13): 272.76695919036865 sec
# validation loop time (for epoch: 13): 0.7559623718261719 sec
#
#
# m : 1
# after 14 epochs... yt_down range (train): [0.04361774027347565 1.2345671653747559]
# after 14 epochs... yt_down range (test): [0.0453202947974205 3.8338396549224854]
# training loop time (for epoch: 14): 272.7825698852539 sec
# validation loop time (for epoch: 14): 0.7539217472076416 sec
#
#
# m : 1
# after 15 epochs... yt_down range (train): [0.04408146068453789 1.0932070016860962]
# after 15 epochs... yt_down range (test): [0.046269968152046204 3.8465516567230225]
# training loop time (for epoch: 15): 272.9661567211151 sec
# validation loop time (for epoch: 15): 0.7534451484680176 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 1
# after 16 epochs... yt_down range (train): [0.048211898654699326 2.8046133518218994]
# after 16 epochs... yt_down range (test): [0.04264913499355316 3.8324453830718994]
# training loop time (for epoch: 16): 272.5024223327637 sec
# validation loop time (for epoch: 16): 0.7536985874176025 sec
#
#
# m : 1
# after 17 epochs... yt_down range (train): [0.046635840088129044 3.306084632873535]
# after 17 epochs... yt_down range (test): [0.045497458428144455 3.8648154735565186]
# training loop time (for epoch: 17): 272.3589913845062 sec
# validation loop time (for epoch: 17): 0.7538566589355469 sec
#
#
# m : 1
# after 18 epochs... yt_down range (train): [0.04481423273682594 1.9173966646194458]
# after 18 epochs... yt_down range (test): [0.04263399913907051 3.835162401199341]
# training loop time (for epoch: 18): 272.54526448249817 sec
# validation loop time (for epoch: 18): 0.7537930011749268 sec
#
#
# m : 1
# after 19 epochs... yt_down range (train): [0.044934067875146866 1.8641916513442993]
# after 19 epochs... yt_down range (test): [0.04354921355843544 3.8311867713928223]
# training loop time (for epoch: 19): 272.94286012649536 sec
# validation loop time (for epoch: 19): 0.7546701431274414 sec
#
#
# m : 1
# after 20 epochs... yt_down range (train): [0.04405790939927101 2.519669532775879]
# after 20 epochs... yt_down range (test): [0.04384087026119232 3.8648808002471924]
# training loop time (for epoch: 20): 273.70075845718384 sec
# validation loop time (for epoch: 20): 0.7528231143951416 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 1
# after 21 epochs... yt_down range (train): [0.04443660005927086 2.4618921279907227]
# after 21 epochs... yt_down range (test): [0.04460326209664345 3.789475679397583]
# training loop time (for epoch: 21): 273.1664423942566 sec
# validation loop time (for epoch: 21): 0.754601240158081 sec
#
#
# m : 1
# after 22 epochs... yt_down range (train): [0.0457165390253067 2.235769271850586]
# after 22 epochs... yt_down range (test): [0.043956127017736435 3.858877420425415]
# training loop time (for epoch: 22): 273.306845664978 sec
# validation loop time (for epoch: 22): 0.7537426948547363 sec
#
#
# m : 1
# after 23 epochs... yt_down range (train): [0.04762993007898331 2.11263370513916]
# after 23 epochs... yt_down range (test): [0.04433491453528404 3.8506219387054443]
# training loop time (for epoch: 23): 272.5599308013916 sec
# validation loop time (for epoch: 23): 0.7540552616119385 sec
#
#
# m : 1
# after 24 epochs... yt_down range (train): [0.04374630004167557 1.8022183179855347]
# after 24 epochs... yt_down range (test): [0.04416308552026749 3.8813672065734863]
# training loop time (for epoch: 24): 272.3365523815155 sec
# validation loop time (for epoch: 24): 0.7529034614562988 sec
#
#
# m : 1
# after 25 epochs... yt_down range (train): [0.045692939311265945 1.6813619136810303]
# after 25 epochs... yt_down range (test): [0.04381449520587921 3.833270788192749]
# training loop time (for epoch: 25): 272.73406171798706 sec
# validation loop time (for epoch: 25): 0.7548458576202393 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 1
# after 26 epochs... yt_down range (train): [0.048868484795093536 6.935117244720459]
# after 26 epochs... yt_down range (test): [0.04439810663461685 3.8575778007507324]
# training loop time (for epoch: 26): 272.47384238243103 sec
# validation loop time (for epoch: 26): 0.7520184516906738 sec
#
#
# m : 1
# after 27 epochs... yt_down range (train): [0.04704190418124199 1.8496640920639038]
# after 27 epochs... yt_down range (test): [0.04553912580013275 3.8413238525390625]
# training loop time (for epoch: 27): 272.8093774318695 sec
# validation loop time (for epoch: 27): 0.7553117275238037 sec
#
#
# m : 1
# after 28 epochs... yt_down range (train): [0.045132242143154144 3.8372068405151367]
# after 28 epochs... yt_down range (test): [0.044772919267416 3.8558380603790283]
# training loop time (for epoch: 28): 273.0714473724365 sec
# validation loop time (for epoch: 28): 0.7547335624694824 sec
#
#
# m : 1
# after 29 epochs... yt_down range (train): [0.044169384986162186 3.780282735824585]
# after 29 epochs... yt_down range (test): [0.04497772455215454 3.847269296646118]
# training loop time (for epoch: 29): 272.68392181396484 sec
# validation loop time (for epoch: 29): 0.7536382675170898 sec
#
#
# m : 1
# after 30 epochs... yt_down range (train): [0.04482539743185043 3.741676092147827]
# after 30 epochs... yt_down range (test): [0.04518180713057518 3.870330572128296]
# training loop time (for epoch: 30): 272.6646018028259 sec
# validation loop time (for epoch: 30): 0.7546722888946533 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 1
