# %%
# %load_ext autoreload
# %autoreload 2

from main_reconstruction_swinIR import safe_do_exps

# %%
# !ls ../figs/
# Out:
# bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalUpsample
# bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalUpsample_default
# bbbcHumanMCF7cellsW4_swinIRwCustomV2_x16_comp

# %%
name= 'bbbcHumanMCF7cellsW4_swinIRwCustomV2_EvalUpsample_default'

exp_dir= f'../figs/{name}' #'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs'
save_dir_special_root = f'../figs/{name}' #f'/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/results/aim2/figs/{name}'

# !rm -rf $exp_dir
# !mkdir $exp_dir

# !rm -rf $save_dir_special_root
# !mkdir $save_dir_special_root

# %%
count_only = False

device = 'cuda:1'

exps = {
        'DATASET.name': ['bbbcHumanMCF7cellsW4'],
    
        'MODEL.MODEL_A.rotation_lambda': ['10000.0'],
        'MODEL.MODEL_A.lambda_scale_factor': ['3'],
        'MODEL.MODEL_H.T': ['1'], 
        'MODEL.MODEL_H.lr_H': ['0.0'],
    
        'DATASET.img_size':  ['64'], #256
        'DATASET.num_samples_train': ['3000'], #'10000-> 1400 sec/ epoch' , 3000-> 440 sec/ epoch (18.3hrs/ exp)  
        'DATASET.num_samples_valtest': ['25'],
        'DATASET.batch_size_train': ['8'], #32
}

general_opts= ['TRAIN.show_results_epoch', '5', #5
                'TRAIN.epochs', '150']  #150


safe_do_exps(exps, general_opts, device, exp_dir = exp_dir, save_special= True, count_only= count_only, save_dir_special_root= save_dir_special_root)
# Out:
# after 96 epochs... yt_down range (train): [0.035182155668735504 1.5772035121917725]
# after 96 epochs... yt_down range (test): [0.03567696362733841 4.206716537475586]
# training loop time (for epoch: 96): 78.96222043037415 sec
# validation loop time (for epoch: 96): 0.09213376045227051 sec
#
#
# m : 2
# after 97 epochs... yt_down range (train): [0.03561533987522125 2.475750684738159]
# after 97 epochs... yt_down range (test): [0.03586847707629204 4.239587306976318]
# training loop time (for epoch: 97): 80.09146690368652 sec
# validation loop time (for epoch: 97): 0.09501194953918457 sec
#
#
# m : 2
# after 98 epochs... yt_down range (train): [0.03487417474389076 2.152923822402954]
# after 98 epochs... yt_down range (test): [0.03610315918922424 4.24447774887085]
# training loop time (for epoch: 98): 80.23127341270447 sec
# validation loop time (for epoch: 98): 0.09363889694213867 sec
#
#
# m : 2
# after 99 epochs... yt_down range (train): [0.052566807717084885 1.951788067817688]
# after 99 epochs... yt_down range (test): [0.037642672657966614 4.235292911529541]
# training loop time (for epoch: 99): 80.23303079605103 sec
# validation loop time (for epoch: 99): 0.09850239753723145 sec
#
#
# m : 3
# after 100 epochs... yt_down range (train): [0.03993457555770874 3.582339286804199]
# after 100 epochs... yt_down range (test): [0.03300449252128601 4.390074729919434]
# training loop time (for epoch: 100): 80.43198752403259 sec
# validation loop time (for epoch: 100): 0.0910186767578125 sec
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# m : 3
# after 101 epochs... yt_down range (train): [0.032116591930389404 4.057508945465088]
# after 101 epochs... yt_down range (test): [0.033875610679388046 4.438420295715332]
# training loop time (for epoch: 101): 74.20058059692383 sec
# validation loop time (for epoch: 101): 0.09426999092102051 sec
#
#
# m : 3
# after 102 epochs... yt_down range (train): [0.046426206827163696 1.4295997619628906]
# after 102 epochs... yt_down range (test): [0.03496769070625305 4.435338973999023]
# training loop time (for epoch: 102): 75.73211193084717 sec
# validation loop time (for epoch: 102): 0.09320473670959473 sec
#
#
# m : 3
# after 103 epochs... yt_down range (train): [0.03459189832210541 2.5797619819641113]
# after 103 epochs... yt_down range (test): [0.03440582752227783 4.399820804595947]
# training loop time (for epoch: 103): 81.33583545684814 sec
# validation loop time (for epoch: 103): 0.09503865242004395 sec
#
#
# m : 3
# after 104 epochs... yt_down range (train): [0.03377549350261688 1.867939829826355]
# after 104 epochs... yt_down range (test): [0.030629746615886688 4.4076008796691895]
# training loop time (for epoch: 104): 81.73117589950562 sec
# validation loop time (for epoch: 104): 0.10670804977416992 sec
#
#
# m : 3
