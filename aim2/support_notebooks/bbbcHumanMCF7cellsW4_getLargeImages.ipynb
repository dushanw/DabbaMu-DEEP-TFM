# %%
zip_dir = '/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/zip_files'
zip_dir = '/home/udith/udith_works/datasets/bbbc021_zips'

import glob
import shutil

img_dir = '/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/img_files'
#img_dir= '/home/udith/udith_works/datasets/bbbcHumanMCF7cells/img_files'

# %%
import cv2
import matplotlib.pyplot as plt
import torch
import torchvision
import numpy as np

# %%
channel_type= ['w1', 'w2', 'w4'][2]

all_img_files = sorted(glob.glob(f'{img_dir}/*/*_{channel_type}*.tif'))
val_img_files = all_img_files[int(len(all_img_files)*0.98):int(len(all_img_files)*0.99)]

x_=[]
for img_file_dir in val_img_files:
    x_.append(plt.imread(img_file_dir))
x_ = np.array(x_)

# %%
import os

# %%
len(val_img_files)
# Out:
# 132

# %%
save_dir = '/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/few_sample_large_imgs'
try:shutil.rmtree(save_dir)
except:pass
os.mkdir(save_dir)

imgs= (x_.astype('float'))/65535.0
#ids= np.random.randint(0, len(x_), (20,))
ids= range(100, 132)
for idx in [3, 9, 57, 94]: #[3, 9, 57, 94]
    #idx= np.random.randint(0, len(x_))
    plt.imshow(imgs[idx])
    plt.colorbar()
    cv2.imwrite(f'{save_dir}/{idx}.png', (imgs[idx]*256).astype('uint8')) ## SHOULD BE 255.0 RIGHT (But will not be an issue, cause no image has that value)
    plt.show()
    print(idx)
# Out:
# 3
# 9
# 57
# 94

# %%
# !zip -r 'bbbcHumanMCF7cells_sample_large_imgs.zip' '/n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/few_sample_large_imgs/'
# Out:
# updating: n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/few_sample_large_imgs/ (stored 0%)
# updating: n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/few_sample_large_imgs/3.png (deflated 2%)
# updating: n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/few_sample_large_imgs/9.png (deflated 2%)
#   adding: n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/few_sample_large_imgs/94.png (deflated 3%)
#   adding: n/holylfs/LABS/wadduwage_lab/Lab/uom_Udith/datasets/bbbcHumanMCF7cells/few_sample_large_imgs/57.png (deflated 3%)
